# %%
#https://drivendata.github.io/cookiecutter-data-science/

# %%
import csv
for row in csv.reader(open("../../data/external/icwsm2020_data/all_data.csv", "r"), delimiter='\t'):
    print(row)
# Out:
# ['_id', 'dataset', 'of_id', 'sexist', 'text', 'toxicity', 'tweet_id']
# ['5d654901ce2c6bd733475b8d', 'benevolent', '', 'False', '#InternationalWomensDay because I\'ve witnessed a man refer to an executive woman as "A Good Girl" #BeBoldForChange', '0.3672823', '8.394023124393288e+17']
# ['5d654901ce2c6bd733475b8e', 'benevolent', '', 'True', 'A lot of females try to think like a man to avoid getting hurt/played instead of just being a woman. Take a chance ,love again.', '0.13931698', '8.470970388105708e+17']
# ['5d654901ce2c6bd733475b8f', 'benevolent', '', 'False', '"a woman with a voice is a strong woman." #womensday', '0.08796926599999999', '']
# ['5d654901ce2c6bd733475b90', 'benevolent', '', 'False', 'Instead of looking for a girl who is hot try looking for one who is respectful, kind and smart, it creates a better outcome for everyone.', '0.37901193', '8.471293452148326e+17']
# ...

# %%
for row in csv.reader(open("../../data/external/icwsm2020_data/all_data_annotations.csv", "r"), delimiter='\t'):
    print(row)
# Out:
# ['_id', 'dataset', 'WorkerId', 'content', 'phrasing']
# ['5d654901ce2c6bd733475b8d', 'benevolent', '0', '2', '3']
# ['5d654901ce2c6bd733475b8d', 'benevolent', '1', '6', '3']
# ['5d654901ce2c6bd733475b8d', 'benevolent', '2', '6', '3']
# ['5d654901ce2c6bd733475b8d', 'benevolent', '3', '6', '3']
# ['5d654901ce2c6bd733475b8d', 'benevolent', '4', '6', '3']
# ['5d654901ce2c6bd733475b8e', 'benevolent', '1', '2', '3']
# ['5d654901ce2c6bd733475b8e', 'benevolent', '0', '1', '3']
# ['5d654901ce2c6bd733475b8e', 'benevolent', '2', '2', '3']
# ['5d654901ce2c6bd733475b8e', 'benevolent', '5', '2', '3']
# ['5d654901ce2c6bd733475b8e', 'benevolent', '3', '2', '3']
# ['5d654901ce2c6bd733475b8f', 'benevolent', '6', '6', '3']
# ['5d654901ce2c6bd733475b8f', 'benevolent', '2', '6', '3']
# ['5d654901ce2c6bd733475b8f', 'benevolent', '7', '6', '3']
# ['5d654901ce2c6bd733475b8f', 'benevolent', '3', '6', '3']
# ['5d654901ce2c6bd733475b8f', 'benevolent', '4', '6', '3']
# ...

# %%
git clone "https://github.com/gesiscss/sexism_custom_classifier.git" /Users/ezgidaldal/Jupyter_workspace/master_thesis/github/

# %%
import numpy
